# %%
V = CombinatorialFreeModule(QQ, ["a","b","c"])

# %%
B=V.basis()

# %%
B["a"]*7
# Out:
# 7*B['a']

# %%
Vq=V.quotient_module([B["a"]+B["b"]])

# %%
Vq
# Out:
# Free module generated by {'b', 'c'} over Rational Field

# %%
Vq.basis()
# Out:
# Finite family {'b': B['b'], 'c': B['c']}

# %%
W=CombinatorialFreeModule(QQ,["x","y"])
WB = W.basis()

# %%
def ffun(b):
    if b == "b":
        return WB["x"]+9*WB["y"]
    if b == "c":
        return -WB["x"]
f=Vq.module_morphism(on_basis= ffun,codomain=W)

# %%
Vq.module_morphism?

# %%
f(7*B["b"]+B["c"])
# Out:
# 6*B['x'] + 63*B['y']

# %%
f.matrix()
# Out:
# [ 1 -1]
# [ 9  0]

# %%
VW=tensor([V,W])

# %%
tB=VW.basis()

# %%
list(tB)
# Out:
# [B['a'] # B['x'],
#  B['a'] # B['y'],
#  B['b'] # B['x'],
#  B['b'] # B['y'],
#  B['c'] # B['x'],
#  B['c'] # B['y']]

# %%
tB[("a","x")]
# Out:
# B['a'] # B['x']

# %%
R.<q,w> = PolynomialRing(QQ)

# %%
VR = CombinatorialFreeModule(QQ, [q^2,q*w,w^2])

# %%
VR
# Out:
# Free module generated by {q^2, q*w, w^2} over Rational Field

# %%
B=VR.basis()

# %%
B[q^2]
# Out:
# B[q^2]

# %%
V
# Out:
# Free module generated by {'a', 'b', 'c'} over Rational Field

# %%
Vd=V.Hom(QQ)

# %%
RR.<a,b,c> =QQ[]
RRR.<x,y> = QQ[]
T = tensor([RR,RRR])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-57-2bed69eec89d> in <module>()
#       1 RR = QQ['a, b, c']; (a, b, c,) = RR._first_ngens(3)
#       2 RRR = QQ['x, y']; (x, y,) = RRR._first_ngens(2)
# ----> 3 T = tensor([RR,RRR])
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/categories/covariant_functorial_construction.pyc in __call__(self, args, **kwargs)
#     219         """
#     220         args = tuple(args) # a bit brute force; let's see if this becomes a bottleneck later
# --> 221         assert(all( hasattr(arg, self._functor_name) for arg in args))
#     222         assert(len(args) > 0)
#     223         return getattr(args[0], self._functor_name)(*args[1:], **kwargs)
#
# AssertionError:

# %%
tensor?

# %%
S=SymmetricFunctions(QQ).schur()

# %%
S[5,4].expand(3)(1,1,1)
# Out:
# 35

# %%
S[3,3].expand(3)(1,1,1)
# Out:
# 10

# %%
S[3].expand(3)(1,1,1)
# Out:
# 10

# %%
S[2,1].expand(3)(1,1,1)
# Out:
# 8

# %%
35+10+10+8
# Out:
# 63

# %%
left.
